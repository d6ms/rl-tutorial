# %%
import gym
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from JSAnimation.IPython_display import display_animation
from matplotlib import animation
from IPython.display import display
 

def display_frames_as_gif(frames):
    """
    Displays a list of frames as a gif, with controls
    """
    plt.figure(figsize=(frames[0].shape[1] / 72.0, frames[0].shape[0] / 72.0),
               dpi=72)
    patch = plt.imshow(frames[0])
    plt.axis('off')
 
    def animate(i):
        patch.set_data(frames[i])
 
    anim = animation.FuncAnimation(plt.gcf(), animate, frames=len(frames),
                                   interval=50)
 
    anim.save('movie_cartpole_DQN.mp4')  # 動画のファイル名と保存です
    display(display_animation(anim, default_mode='loop'))

# %%
# namedtupleを生成
from collections import namedtuple
 
Transition = namedtuple(
    'Transition', ('state', 'action', 'next_state', 'reward'))

# %%
ENV = 'CartPole-v0'  # 使用する課題名
GAMMA = 0.99  # 時間割引率
MAX_STEPS = 200  # 1試行のstep数
NUM_EPISODES = 500  # 最大試行回数

# %%
# 経験を保存するメモリクラスを定義します
 
class ReplayMemory:
 
    def __init__(self, CAPACITY):
        self.capacity = CAPACITY  # メモリの最大長さ
        self.memory = []  # 経験を保存する変数
        self.index = 0  # 保存するindexを示す変数
 
    def push(self, state, action, state_next, reward):
        """state, action, state_next, rewardをメモリに保存します"""
 
        if len(self.memory) < self.capacity:
            self.memory.append(None)  # メモリが満タンでないときは足す
 
        # namedtupleのTransitionを使用し、値とフィールド名をペアにして保存します
        self.memory[self.index] = Transition(state, action, state_next, reward)
 
        self.index = (self.index + 1) % self.capacity  # 保存するindexを1つずらす
 
    def sample(self, batch_size):
        """batch_size分だけ、ランダムに保存内容を取り出します"""
        return random.sample(self.memory, batch_size)
 
    def __len__(self):
        return len(self.memory)

# %%
# エージェントが持つ脳となるクラスです、DQNを実行します
# Q関数をディープラーニングのネットワークをクラスとして定義
 
import random
import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
from torch.autograd import Variable
 
BATCH_SIZE = 32
CAPACITY = 10000
 

class Brain:
    def __init__(self, num_states, num_actions):
        self.num_states = num_states  # CartPoleは状態数4を取得
        self.num_actions = num_actions  # CartPoleの行動（右に左に押す）の2を取得
 
        # 経験を記憶するメモリオブジェクトを生成
        self.memory = ReplayMemory(CAPACITY)
 
        # ニューラルネットワークを構築
        self.model = nn.Sequential()
        self.model.add_module('fc1', nn.Linear(self.num_states, 32))
        self.model.add_module('relu1', nn.ReLU())
        self.model.add_module('fc2', nn.Linear(32, 32))
        self.model.add_module('relu2', nn.ReLU())
        self.model.add_module('fc3', nn.Linear(32, self.num_actions))
 
        print(self.model)  # ネットワークの形を出力
 
        # 最適化手法の設定
        self.optimizer = optim.Adam(self.model.parameters(), lr=0.0001)
 
    def replay(self):
        """Experience Replayでネットワークの重みを学習 """
 
        # メモリサイズがミニバッチより小さい間は何もしない
        if len(self.memory) < BATCH_SIZE:
            return
 
        # メモリからミニバッチ分のデータを取り出す
        transitions = self.memory.sample(BATCH_SIZE)
 
        # ミニバッチの作成-----------------
 
        # transitionsは1stepごとの(state, action, state_next, reward)が、BATCH_SIZE分格納されている
        # つまり、(state, action, state_next, reward)×BATCH_SIZE
        # これをミニバッチにしたい。つまり
        # (state×BATCH_SIZE, action×BATCH_SIZE, state_next×BATCH_SIZE, reward×BATCH_SIZE)にする
        batch = Transition(*zip(*transitions))
 
        # cartpoleがdoneになっておらず、next_stateがあるかをチェックするマスクを作成
        non_final_mask = torch.ByteTensor(tuple(map(lambda s: s is not None,
                                                    batch.next_state)))
 
        # バッチから状態、行動、報酬を格納（non_finalはdoneになっていないstate）
        # catはConcatenates（結合）のことです。
        # 例えばstateの場合、[torch.FloatTensor of size 1x4]がBATCH_SIZE分並んでいるのですが、
        # それを size BATCH_SIZEx4 に変換します
        state_batch = Variable(torch.cat(batch.state))
        action_batch = Variable(torch.cat(batch.action))
        reward_batch = Variable(torch.cat(batch.reward))
        non_final_next_states = Variable(torch.cat([s for s in batch.next_state
                                                    if s is not None]))
 
        # ミニバッチの作成終了------------------
 
        # ネットワークを推論モードに切り替える
        self.model.eval()
 
        # Q(s_t, a_t)を求める
        # self.model(state_batch)は、[torch.FloatTensor of size BATCH_SIZEx2]になっており、
        # 実行したアクションに対応する[torch.FloatTensor of size BATCH_SIZEx1]にするために
        # gatherを使用します。
        state_action_values = self.model(state_batch).gather(1, action_batch)
 
        # max{Q(s_t+1, a)}値を求める。
        # 次の状態がない場合は0にしておく
        next_state_values = Variable(torch.zeros(
            BATCH_SIZE).type(torch.FloatTensor))
 
        # 次の状態がある場合の値を求める
        # 出力であるdataにアクセスし、max(1)で列方向の最大値の[値、index]を求めます
        # そしてその値（index=0）を出力します
        next_state_values[non_final_mask] = self.model(
            non_final_next_states).data.max(1)[0]
 
        # 教師となるQ(s_t, a_t)値を求める
        expected_state_action_values = reward_batch + GAMMA * next_state_values
 
        # ネットワークを訓練モードに切り替える
        self.model.train()
 
        # 損失関数を計算する。smooth_l1_lossはHuberlossです
        loss = F.smooth_l1_loss(state_action_values,
                                expected_state_action_values)
 
        # ネットワークを更新します
        self.optimizer.zero_grad()  # 勾配をリセット
        loss.backward()  # バックプロパゲーションを計算
        self.optimizer.step()  # 結合パラメータを更新
 
    def decide_action(self, state, episode):
        # ε-greedy法で徐々に最適行動のみを採用する
        epsilon = 0.5 * (1 / (episode + 1))
 
        if epsilon <= np.random.uniform(0, 1):
            self.model.eval()  # ネットワークを推論モードに切り替える
            action = self.model(Variable(state)).data.max(1)[1].view(1, 1)
            # ネットワークの出力の最大値のindexを取り出します = max(1)[1]
            # .view(1,1)はtorch.LongTensor of size 1　を size 1x1 に変換します
 
        else:
            # 0,1の行動をランダムに返す
            action = torch.LongTensor(
                [[random.randrange(self.num_actions)]])  # 0,1の行動をランダムに返す
            # actionは[torch.LongTensor of size 1x1]の形になります
 
        return action

# %%
# CartPoleで動くエージェントクラスです、棒付き台車そのものになります
 

class Agent:
    def __init__(self, num_states, num_actions):
        """課題の状態と行動の数を設定します"""
        self.num_states = num_states  # CartPoleは状態数4を取得
        self.num_actions = num_actions  # CartPoleの行動（右に左に押す）の2を取得
        self.brain = Brain(num_states, num_actions)  # エージェントが行動を決定するための頭脳を生成
 
    def update_q_function(self):
        """Q関数を更新します"""
        self.brain.replay()
 
    def get_action(self, state, step):
        """行動の決定します"""
        action = self.brain.decide_action(state, step)
        return action
 
    def memorize(self, state, action, state_next, reward):
        """memoryオブジェクトに、state, action, state_next, rewardの内容を保存します"""
        self.brain.memory.push(state, action, state_next, reward)

# %%
# CartPoleを実行する環境のクラスです
 

class Environment:
 
    def __init__(self):
        self.env = gym.make(ENV)  # 実行する課題を設定
        self.num_states = self.env.observation_space.shape[0]  # 課題の状態と行動の数を設定
        self.num_actions = self.env.action_space.n  # CartPoleの行動（右に左に押す）の2を取得
        # 環境内で行動するAgentを生成
        self.agent = Agent(self.num_states, self.num_actions)
        self.total_step = np.zeros(10)  # 10試行分の立ち続けたstep数を格納し、平均ステップ数を出力させます
 
    def run(self):
        """メインの実行"""
 
        complete_episodes = 0  # 195step以上連続で立ち続けた試行数
        episode_final = False  # 最後の試行フラグ
        frames = []  # 最後の試行を動画にするために画像を格納する変数
 
        for episode in range(NUM_EPISODES):  # 試行数分繰り返す
            observation = self.env.reset()  # 環境の初期化
            state = observation  # 観測をそのまま状態sとして使用
            state = torch.from_numpy(state).type(
                torch.FloatTensor)  # numpy変数をPyTorchのテンソルに変換
 
            # 今、FloatTensor of size 4になっているので、size 1x4に変換
            state = torch.unsqueeze(state, 0)
 
            for step in range(MAX_STEPS):  # 1エピソードのループ
                if episode_final is True:
                    """framesに各時刻の画像を追加していく"""
                    frames.append(self.env.render(mode='rgb_array'))
 
                action = self.agent.get_action(state, episode)  # 行動を求める
 
                # 行動a_tの実行により、s_{t+1}とdoneフラグを求める
                # actionは、torch.LongTensor of size 1x1になっているので、[0,0]を指定して、中身を取り出す
                observation_next, _, done, _ = self.env.step(int(action[0, 0]))
 
                # episodeの終了評価と、state_nextを設定
                if done:  # ステップ数が200経過するか、一定角度以上傾くとdoneはtrueになる
                    state_next = None  # 次の状態はないので、Noneを格納
                    self.total_step = np.hstack(
                        (self.total_step[1:], step + 1))  # step数を保存
                    if step < 195:
                        reward = torch.FloatTensor(
                            [-1.0])  # 途中でこけたら罰則として報酬-1を与える
                        self.complete_episodes = 0  # 連続成功記録をリセット
                    else:
                        reward = torch.FloatTensor([1.0])  # 立ったまま終了時は報酬1を与える
                        self.complete_episodes = self.complete_episodes + 1  # 連続記録を更新
                else:
                    reward = torch.FloatTensor([0.0])  # 普段は報酬0
                    state_next = observation_next  # 観測をそのまま状態とする
                    state_next = torch.from_numpy(state_next).type(
                        torch.FloatTensor)  # numpyとPyTorchのテンソルに
 
                    # テンソルがsize 4になっているので、size 1x4に変換
                    state_next = torch.unsqueeze(state_next, 0)
 
                # メモリに経験を追加
                self.agent.memorize(state, action, state_next, reward)
 
                # Experience ReplayでQ関数を更新する
                self.agent.update_q_function()
 
                # 観測の更新
                state = state_next
 
                # 終了時の処理
                if done:
                    print('%d Episode: Finished after %d steps：10Average = %.1lf' % (
                        episode, step + 1, self.total_step.mean()))
                    break
 
            if episode_final is True:
                # 動画を保存と描画
                display_frames_as_gif(frames)
                break
 
            # 10連続で200step立ち続けたら成功
            if self.complete_episodes >= 10:
                print('10回連続成功')
                episode_final = True  # 次の試行を描画を行う最終試行とする

# %%
# main クラス
cartpole_env = Environment()
cartpole_env.run()
# Out:
# Sequential(
#   (fc1): Linear(in_features=4, out_features=32, bias=True)
#   (relu1): ReLU()
#   (fc2): Linear(in_features=32, out_features=32, bias=True)
#   (relu2): ReLU()
#   (fc3): Linear(in_features=32, out_features=2, bias=True)
# )
# 0 Episode: Finished after 13 steps：10Average = 1.3
# 1 Episode: Finished after 11 steps：10Average = 2.4
# 2 Episode: Finished after 9 steps：10Average = 3.3
# 3 Episode: Finished after 11 steps：10Average = 4.4
# 4 Episode: Finished after 9 steps：10Average = 5.3
# 5 Episode: Finished after 9 steps：10Average = 6.2
# 6 Episode: Finished after 9 steps：10Average = 7.1
# 7 Episode: Finished after 10 steps：10Average = 8.1
# 8 Episode: Finished after 9 steps：10Average = 9.0
# 9 Episode: Finished after 10 steps：10Average = 10.0
# 10 Episode: Finished after 9 steps：10Average = 9.6
# 11 Episode: Finished after 9 steps：10Average = 9.4
# /Users/d6ms/dev/miniconda3/envs/rl_env/lib/python3.7/site-packages/ipykernel_launcher.py:88: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  /tmp/pip-req-build-rc66hrpz/aten/src/ATen/native/IndexingUtils.h:20.)
# /Users/d6ms/dev/miniconda3/envs/rl_env/lib/python3.7/site-packages/ipykernel_launcher.py:98: UserWarning: Using a target size (torch.Size([32])) that is different to the input size (torch.Size([32, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
# 12 Episode: Finished after 9 steps：10Average = 9.4
# 13 Episode: Finished after 10 steps：10Average = 9.3
# 14 Episode: Finished after 9 steps：10Average = 9.3
# 15 Episode: Finished after 11 steps：10Average = 9.5
# 16 Episode: Finished after 9 steps：10Average = 9.5
# 17 Episode: Finished after 10 steps：10Average = 9.5
# 18 Episode: Finished after 9 steps：10Average = 9.5
# 19 Episode: Finished after 10 steps：10Average = 9.5
# 20 Episode: Finished after 10 steps：10Average = 9.6
# 21 Episode: Finished after 9 steps：10Average = 9.6
# 22 Episode: Finished after 11 steps：10Average = 9.8
# 23 Episode: Finished after 10 steps：10Average = 9.8
# 24 Episode: Finished after 11 steps：10Average = 10.0
# 25 Episode: Finished after 10 steps：10Average = 9.9
# 26 Episode: Finished after 13 steps：10Average = 10.3
# 27 Episode: Finished after 11 steps：10Average = 10.4
# 28 Episode: Finished after 12 steps：10Average = 10.7
# 29 Episode: Finished after 9 steps：10Average = 10.6
# 30 Episode: Finished after 11 steps：10Average = 10.7
# 31 Episode: Finished after 14 steps：10Average = 11.2
# 32 Episode: Finished after 15 steps：10Average = 11.6
# 33 Episode: Finished after 15 steps：10Average = 12.1
# 34 Episode: Finished after 11 steps：10Average = 12.1
# 35 Episode: Finished after 13 steps：10Average = 12.4
# 36 Episode: Finished after 11 steps：10Average = 12.2
# 37 Episode: Finished after 13 steps：10Average = 12.4
# 38 Episode: Finished after 14 steps：10Average = 12.6
# 39 Episode: Finished after 17 steps：10Average = 13.4
# 40 Episode: Finished after 17 steps：10Average = 14.0
# 41 Episode: Finished after 24 steps：10Average = 15.0
# 42 Episode: Finished after 27 steps：10Average = 16.2
# 43 Episode: Finished after 26 steps：10Average = 17.3
# 44 Episode: Finished after 17 steps：10Average = 17.9
# 45 Episode: Finished after 17 steps：10Average = 18.3
# 46 Episode: Finished after 10 steps：10Average = 18.2
# 47 Episode: Finished after 10 steps：10Average = 17.9
# 48 Episode: Finished after 9 steps：10Average = 17.4
# 49 Episode: Finished after 8 steps：10Average = 16.5
# 50 Episode: Finished after 9 steps：10Average = 15.7
# 51 Episode: Finished after 10 steps：10Average = 14.3
# 52 Episode: Finished after 20 steps：10Average = 13.6
# 53 Episode: Finished after 21 steps：10Average = 13.1
# 54 Episode: Finished after 11 steps：10Average = 12.5
# 55 Episode: Finished after 12 steps：10Average = 12.0
# 56 Episode: Finished after 9 steps：10Average = 11.9
# 57 Episode: Finished after 10 steps：10Average = 11.9
# 58 Episode: Finished after 10 steps：10Average = 12.0
# 59 Episode: Finished after 9 steps：10Average = 12.1
# 60 Episode: Finished after 8 steps：10Average = 12.0
# 61 Episode: Finished after 11 steps：10Average = 12.1
# 62 Episode: Finished after 9 steps：10Average = 11.0
# 63 Episode: Finished after 10 steps：10Average = 9.9
# 64 Episode: Finished after 9 steps：10Average = 9.7
# 65 Episode: Finished after 10 steps：10Average = 9.5
# 66 Episode: Finished after 9 steps：10Average = 9.5
# 67 Episode: Finished after 9 steps：10Average = 9.4
# 68 Episode: Finished after 9 steps：10Average = 9.3
# 69 Episode: Finished after 23 steps：10Average = 10.7
# 70 Episode: Finished after 41 steps：10Average = 14.0
# 71 Episode: Finished after 29 steps：10Average = 15.8
# 72 Episode: Finished after 10 steps：10Average = 15.9
# 73 Episode: Finished after 34 steps：10Average = 18.3
# 74 Episode: Finished after 28 steps：10Average = 20.2
# 75 Episode: Finished after 50 steps：10Average = 24.2
# 76 Episode: Finished after 29 steps：10Average = 26.2
# 77 Episode: Finished after 10 steps：10Average = 26.3
# 78 Episode: Finished after 10 steps：10Average = 26.4
# 79 Episode: Finished after 36 steps：10Average = 27.7
# 80 Episode: Finished after 9 steps：10Average = 24.5
# 81 Episode: Finished after 27 steps：10Average = 24.3
# 82 Episode: Finished after 10 steps：10Average = 24.3
# 83 Episode: Finished after 10 steps：10Average = 21.9
# 84 Episode: Finished after 11 steps：10Average = 20.2
# 85 Episode: Finished after 9 steps：10Average = 16.1
# 86 Episode: Finished after 25 steps：10Average = 15.7
# 87 Episode: Finished after 9 steps：10Average = 15.6
# 88 Episode: Finished after 11 steps：10Average = 15.7
# 89 Episode: Finished after 35 steps：10Average = 15.6
# 90 Episode: Finished after 19 steps：10Average = 16.6
# 91 Episode: Finished after 11 steps：10Average = 15.0
# 92 Episode: Finished after 10 steps：10Average = 15.0
# 93 Episode: Finished after 9 steps：10Average = 14.9
# 94 Episode: Finished after 21 steps：10Average = 15.9
# 95 Episode: Finished after 15 steps：10Average = 16.5
# 96 Episode: Finished after 27 steps：10Average = 16.7
# 97 Episode: Finished after 20 steps：10Average = 17.8
# 98 Episode: Finished after 17 steps：10Average = 18.4
# 99 Episode: Finished after 18 steps：10Average = 16.7
# 100 Episode: Finished after 32 steps：10Average = 18.0
# 101 Episode: Finished after 10 steps：10Average = 17.9
# 102 Episode: Finished after 11 steps：10Average = 18.0
# 103 Episode: Finished after 13 steps：10Average = 18.4
# 104 Episode: Finished after 14 steps：10Average = 17.7
# 105 Episode: Finished after 33 steps：10Average = 19.5
# 106 Episode: Finished after 9 steps：10Average = 17.7
# 107 Episode: Finished after 10 steps：10Average = 16.7
# 108 Episode: Finished after 14 steps：10Average = 16.4
# 109 Episode: Finished after 10 steps：10Average = 15.6
# 110 Episode: Finished after 10 steps：10Average = 13.4
# 111 Episode: Finished after 18 steps：10Average = 14.2
# 112 Episode: Finished after 10 steps：10Average = 14.1
# 113 Episode: Finished after 17 steps：10Average = 14.5
# 114 Episode: Finished after 15 steps：10Average = 14.6
# 115 Episode: Finished after 20 steps：10Average = 13.3
# 116 Episode: Finished after 10 steps：10Average = 13.4
# 117 Episode: Finished after 9 steps：10Average = 13.3
# 118 Episode: Finished after 15 steps：10Average = 13.4
# 119 Episode: Finished after 18 steps：10Average = 14.2
# 120 Episode: Finished after 17 steps：10Average = 14.9
# 121 Episode: Finished after 10 steps：10Average = 14.1
# 122 Episode: Finished after 9 steps：10Average = 14.0
# 123 Episode: Finished after 10 steps：10Average = 13.3
# 124 Episode: Finished after 9 steps：10Average = 12.7
# 125 Episode: Finished after 10 steps：10Average = 11.7
# 126 Episode: Finished after 9 steps：10Average = 11.6
# 127 Episode: Finished after 10 steps：10Average = 11.7
# 128 Episode: Finished after 10 steps：10Average = 11.2
# 129 Episode: Finished after 13 steps：10Average = 10.7
# 130 Episode: Finished after 19 steps：10Average = 10.9
# 131 Episode: Finished after 15 steps：10Average = 11.4
# 132 Episode: Finished after 13 steps：10Average = 11.8
# 133 Episode: Finished after 17 steps：10Average = 12.5
# 134 Episode: Finished after 17 steps：10Average = 13.3
# 135 Episode: Finished after 14 steps：10Average = 13.7
# 136 Episode: Finished after 10 steps：10Average = 13.8
# 137 Episode: Finished after 21 steps：10Average = 14.9
# 138 Episode: Finished after 10 steps：10Average = 14.9
# 139 Episode: Finished after 11 steps：10Average = 14.7
# 140 Episode: Finished after 11 steps：10Average = 13.9
# 141 Episode: Finished after 10 steps：10Average = 13.4
# 142 Episode: Finished after 9 steps：10Average = 13.0
# 143 Episode: Finished after 10 steps：10Average = 12.3
# 144 Episode: Finished after 9 steps：10Average = 11.5
# 145 Episode: Finished after 9 steps：10Average = 11.0
# 146 Episode: Finished after 10 steps：10Average = 11.0
# 147 Episode: Finished after 10 steps：10Average = 9.9
# 148 Episode: Finished after 16 steps：10Average = 10.5
# 149 Episode: Finished after 12 steps：10Average = 10.6
# 150 Episode: Finished after 22 steps：10Average = 11.7
# 151 Episode: Finished after 10 steps：10Average = 11.7
# 152 Episode: Finished after 9 steps：10Average = 11.7
# 153 Episode: Finished after 9 steps：10Average = 11.6
# 154 Episode: Finished after 11 steps：10Average = 11.8
# 155 Episode: Finished after 10 steps：10Average = 11.9
# 156 Episode: Finished after 14 steps：10Average = 12.3
# 157 Episode: Finished after 9 steps：10Average = 12.2
# 158 Episode: Finished after 10 steps：10Average = 11.6
# 159 Episode: Finished after 10 steps：10Average = 11.4
# 160 Episode: Finished after 9 steps：10Average = 10.1
# 161 Episode: Finished after 10 steps：10Average = 10.1
# 162 Episode: Finished after 11 steps：10Average = 10.3
# 163 Episode: Finished after 10 steps：10Average = 10.4
# 164 Episode: Finished after 12 steps：10Average = 10.5
# 165 Episode: Finished after 12 steps：10Average = 10.7
# 166 Episode: Finished after 16 steps：10Average = 10.9
# 167 Episode: Finished after 10 steps：10Average = 11.0
# 168 Episode: Finished after 11 steps：10Average = 11.1
# 169 Episode: Finished after 13 steps：10Average = 11.4
# 170 Episode: Finished after 13 steps：10Average = 11.8
# 171 Episode: Finished after 9 steps：10Average = 11.7
# 172 Episode: Finished after 9 steps：10Average = 11.5
# 173 Episode: Finished after 9 steps：10Average = 11.4
# 174 Episode: Finished after 9 steps：10Average = 11.1
# 175 Episode: Finished after 10 steps：10Average = 10.9
# 176 Episode: Finished after 13 steps：10Average = 10.6
# 177 Episode: Finished after 15 steps：10Average = 11.1
# 178 Episode: Finished after 10 steps：10Average = 11.0
# 179 Episode: Finished after 16 steps：10Average = 11.3
# 180 Episode: Finished after 10 steps：10Average = 11.0
# 181 Episode: Finished after 9 steps：10Average = 11.0
# 182 Episode: Finished after 12 steps：10Average = 11.3
# 183 Episode: Finished after 10 steps：10Average = 11.4
# 184 Episode: Finished after 13 steps：10Average = 11.8
# 185 Episode: Finished after 10 steps：10Average = 11.8
# 186 Episode: Finished after 13 steps：10Average = 11.8
# 187 Episode: Finished after 11 steps：10Average = 11.4
# 188 Episode: Finished after 9 steps：10Average = 11.3
# 189 Episode: Finished after 15 steps：10Average = 11.2
# 190 Episode: Finished after 15 steps：10Average = 11.7
# 191 Episode: Finished after 15 steps：10Average = 12.3
# 192 Episode: Finished after 9 steps：10Average = 12.0
# 193 Episode: Finished after 10 steps：10Average = 12.0
# 194 Episode: Finished after 10 steps：10Average = 11.7
# 195 Episode: Finished after 10 steps：10Average = 11.7
# 196 Episode: Finished after 10 steps：10Average = 11.4
# 197 Episode: Finished after 12 steps：10Average = 11.5
# 198 Episode: Finished after 10 steps：10Average = 11.6
# 199 Episode: Finished after 10 steps：10Average = 11.1
# 200 Episode: Finished after 10 steps：10Average = 10.6
# 201 Episode: Finished after 9 steps：10Average = 10.0
# 202 Episode: Finished after 18 steps：10Average = 10.9
# 203 Episode: Finished after 11 steps：10Average = 11.0
# 204 Episode: Finished after 8 steps：10Average = 10.8
# 205 Episode: Finished after 11 steps：10Average = 10.9
# 206 Episode: Finished after 16 steps：10Average = 11.5
# 207 Episode: Finished after 10 steps：10Average = 11.3
# 208 Episode: Finished after 10 steps：10Average = 11.3
# 209 Episode: Finished after 9 steps：10Average = 11.2
# 210 Episode: Finished after 9 steps：10Average = 11.1
# 211 Episode: Finished after 9 steps：10Average = 11.1
# 212 Episode: Finished after 11 steps：10Average = 10.4
# 213 Episode: Finished after 10 steps：10Average = 10.3
# 214 Episode: Finished after 10 steps：10Average = 10.5
# 215 Episode: Finished after 10 steps：10Average = 10.4
# 216 Episode: Finished after 10 steps：10Average = 9.8
# 217 Episode: Finished after 9 steps：10Average = 9.7
# 218 Episode: Finished after 10 steps：10Average = 9.7
# 219 Episode: Finished after 10 steps：10Average = 9.8
# 220 Episode: Finished after 9 steps：10Average = 9.8
# 221 Episode: Finished after 9 steps：10Average = 9.8
# 222 Episode: Finished after 13 steps：10Average = 10.0
# 223 Episode: Finished after 16 steps：10Average = 10.6
# 224 Episode: Finished after 9 steps：10Average = 10.5
# 225 Episode: Finished after 9 steps：10Average = 10.4
# 226 Episode: Finished after 10 steps：10Average = 10.4
# 227 Episode: Finished after 10 steps：10Average = 10.5
# 228 Episode: Finished after 10 steps：10Average = 10.5
# 229 Episode: Finished after 10 steps：10Average = 10.5
# 230 Episode: Finished after 10 steps：10Average = 10.6
# 231 Episode: Finished after 10 steps：10Average = 10.7
# 232 Episode: Finished after 10 steps：10Average = 10.4
# 233 Episode: Finished after 10 steps：10Average = 9.8
# 234 Episode: Finished after 10 steps：10Average = 9.9
# 235 Episode: Finished after 9 steps：10Average = 9.9
# 236 Episode: Finished after 9 steps：10Average = 9.8
# 237 Episode: Finished after 9 steps：10Average = 9.7
# 238 Episode: Finished after 9 steps：10Average = 9.6
# 239 Episode: Finished after 10 steps：10Average = 9.6
# 240 Episode: Finished after 18 steps：10Average = 10.4
# 241 Episode: Finished after 10 steps：10Average = 10.4
# 242 Episode: Finished after 9 steps：10Average = 10.3
# 243 Episode: Finished after 10 steps：10Average = 10.3
# 244 Episode: Finished after 10 steps：10Average = 10.3
# 245 Episode: Finished after 19 steps：10Average = 11.3
# 246 Episode: Finished after 10 steps：10Average = 11.4
# 247 Episode: Finished after 9 steps：10Average = 11.4
# 248 Episode: Finished after 10 steps：10Average = 11.5
# 249 Episode: Finished after 10 steps：10Average = 11.5
# 250 Episode: Finished after 18 steps：10Average = 11.5
# 251 Episode: Finished after 9 steps：10Average = 11.4
# 252 Episode: Finished after 18 steps：10Average = 12.3
# 253 Episode: Finished after 9 steps：10Average = 12.2
# 254 Episode: Finished after 10 steps：10Average = 12.2
# 255 Episode: Finished after 10 steps：10Average = 11.3
# 256 Episode: Finished after 10 steps：10Average = 11.3
# 257 Episode: Finished after 9 steps：10Average = 11.3
# 258 Episode: Finished after 9 steps：10Average = 11.2
# 259 Episode: Finished after 9 steps：10Average = 11.1
# 260 Episode: Finished after 9 steps：10Average = 10.2
# 261 Episode: Finished after 9 steps：10Average = 10.2
# 262 Episode: Finished after 9 steps：10Average = 9.3
# 263 Episode: Finished after 9 steps：10Average = 9.3
# 264 Episode: Finished after 9 steps：10Average = 9.2
# 265 Episode: Finished after 10 steps：10Average = 9.2
# 266 Episode: Finished after 10 steps：10Average = 9.2
# 267 Episode: Finished after 9 steps：10Average = 9.2
# 268 Episode: Finished after 9 steps：10Average = 9.2
# 269 Episode: Finished after 22 steps：10Average = 10.5
# 270 Episode: Finished after 10 steps：10Average = 10.6
# 271 Episode: Finished after 8 steps：10Average = 10.5
# 272 Episode: Finished after 10 steps：10Average = 10.6
# 273 Episode: Finished after 18 steps：10Average = 11.5
# 274 Episode: Finished after 10 steps：10Average = 11.6
# 275 Episode: Finished after 10 steps：10Average = 11.6
# 276 Episode: Finished after 10 steps：10Average = 11.6
# 277 Episode: Finished after 10 steps：10Average = 11.7
# 278 Episode: Finished after 9 steps：10Average = 11.7
# 279 Episode: Finished after 9 steps：10Average = 10.4
# 280 Episode: Finished after 11 steps：10Average = 10.5
# 281 Episode: Finished after 11 steps：10Average = 10.8
# 282 Episode: Finished after 9 steps：10Average = 10.7
# 283 Episode: Finished after 10 steps：10Average = 9.9
# 284 Episode: Finished after 10 steps：10Average = 9.9
# 285 Episode: Finished after 9 steps：10Average = 9.8
# 286 Episode: Finished after 10 steps：10Average = 9.8
# 287 Episode: Finished after 11 steps：10Average = 9.9
# 288 Episode: Finished after 10 steps：10Average = 10.0
# 289 Episode: Finished after 10 steps：10Average = 10.1
# 290 Episode: Finished after 9 steps：10Average = 9.9
# 291 Episode: Finished after 11 steps：10Average = 9.9
# 292 Episode: Finished after 10 steps：10Average = 10.0
# 293 Episode: Finished after 10 steps：10Average = 10.0
# 294 Episode: Finished after 10 steps：10Average = 10.0
# 295 Episode: Finished after 10 steps：10Average = 10.1
# 296 Episode: Finished after 10 steps：10Average = 10.1
# 297 Episode: Finished after 10 steps：10Average = 10.0
# 298 Episode: Finished after 13 steps：10Average = 10.3
# 299 Episode: Finished after 8 steps：10Average = 10.1
# 300 Episode: Finished after 10 steps：10Average = 10.2
# 301 Episode: Finished after 10 steps：10Average = 10.1
# 302 Episode: Finished after 8 steps：10Average = 9.9
# 303 Episode: Finished after 9 steps：10Average = 9.8
# 304 Episode: Finished after 10 steps：10Average = 9.8
# 305 Episode: Finished after 10 steps：10Average = 9.8
# 306 Episode: Finished after 9 steps：10Average = 9.7
# 307 Episode: Finished after 9 steps：10Average = 9.6
# 308 Episode: Finished after 10 steps：10Average = 9.3
# 309 Episode: Finished after 16 steps：10Average = 10.1
# 310 Episode: Finished after 10 steps：10Average = 10.1
# 311 Episode: Finished after 10 steps：10Average = 10.1
# 312 Episode: Finished after 9 steps：10Average = 10.2
# 313 Episode: Finished after 10 steps：10Average = 10.3
# 314 Episode: Finished after 10 steps：10Average = 10.3
# 315 Episode: Finished after 13 steps：10Average = 10.6
# 316 Episode: Finished after 10 steps：10Average = 10.7
# 317 Episode: Finished after 9 steps：10Average = 10.7
# 318 Episode: Finished after 9 steps：10Average = 10.6
# 319 Episode: Finished after 9 steps：10Average = 9.9
# 320 Episode: Finished after 18 steps：10Average = 10.7
# 321 Episode: Finished after 10 steps：10Average = 10.7
# 322 Episode: Finished after 9 steps：10Average = 10.7
# 323 Episode: Finished after 10 steps：10Average = 10.7
# 324 Episode: Finished after 10 steps：10Average = 10.7
# 325 Episode: Finished after 9 steps：10Average = 10.3
# 326 Episode: Finished after 13 steps：10Average = 10.6
# 327 Episode: Finished after 9 steps：10Average = 10.6
# 328 Episode: Finished after 9 steps：10Average = 10.6
# 329 Episode: Finished after 9 steps：10Average = 10.6
# 330 Episode: Finished after 10 steps：10Average = 9.8
# 331 Episode: Finished after 11 steps：10Average = 9.9
# 332 Episode: Finished after 9 steps：10Average = 9.9
# 333 Episode: Finished after 9 steps：10Average = 9.8
# 334 Episode: Finished after 9 steps：10Average = 9.7
# 335 Episode: Finished after 9 steps：10Average = 9.7
# 336 Episode: Finished after 9 steps：10Average = 9.3
# 337 Episode: Finished after 9 steps：10Average = 9.3
# 338 Episode: Finished after 8 steps：10Average = 9.2
# 339 Episode: Finished after 8 steps：10Average = 9.1
# 340 Episode: Finished after 10 steps：10Average = 9.1
# 341 Episode: Finished after 10 steps：10Average = 9.0
# 342 Episode: Finished after 18 steps：10Average = 9.9
# 343 Episode: Finished after 9 steps：10Average = 9.9
# 344 Episode: Finished after 9 steps：10Average = 9.9
# 345 Episode: Finished after 14 steps：10Average = 10.4
# 346 Episode: Finished after 9 steps：10Average = 10.4
# 347 Episode: Finished after 19 steps：10Average = 11.4
# 348 Episode: Finished after 9 steps：10Average = 11.5
# 349 Episode: Finished after 8 steps：10Average = 11.5
# 350 Episode: Finished after 10 steps：10Average = 11.5
# 351 Episode: Finished after 10 steps：10Average = 11.5
# 352 Episode: Finished after 10 steps：10Average = 10.7
# 353 Episode: Finished after 9 steps：10Average = 10.7
# 354 Episode: Finished after 16 steps：10Average = 11.4
# 355 Episode: Finished after 18 steps：10Average = 11.8
# 356 Episode: Finished after 9 steps：10Average = 11.8
# 357 Episode: Finished after 10 steps：10Average = 10.9
# 358 Episode: Finished after 9 steps：10Average = 10.9
# 359 Episode: Finished after 9 steps：10Average = 11.0
# 360 Episode: Finished after 9 steps：10Average = 10.9
# 361 Episode: Finished after 10 steps：10Average = 10.9
# 362 Episode: Finished after 10 steps：10Average = 10.9
# 363 Episode: Finished after 10 steps：10Average = 11.0
# 364 Episode: Finished after 10 steps：10Average = 10.4
# 365 Episode: Finished after 8 steps：10Average = 9.4
# 366 Episode: Finished after 9 steps：10Average = 9.4
# 367 Episode: Finished after 9 steps：10Average = 9.3
# 368 Episode: Finished after 9 steps：10Average = 9.3
# 369 Episode: Finished after 10 steps：10Average = 9.4
# 370 Episode: Finished after 9 steps：10Average = 9.4
# 371 Episode: Finished after 10 steps：10Average = 9.4
# 372 Episode: Finished after 10 steps：10Average = 9.4
# 373 Episode: Finished after 10 steps：10Average = 9.4
# 374 Episode: Finished after 9 steps：10Average = 9.3
# 375 Episode: Finished after 10 steps：10Average = 9.5
# 376 Episode: Finished after 10 steps：10Average = 9.6
# 377 Episode: Finished after 9 steps：10Average = 9.6
# 378 Episode: Finished after 8 steps：10Average = 9.5
# 379 Episode: Finished after 10 steps：10Average = 9.5
# 380 Episode: Finished after 11 steps：10Average = 9.7
# 381 Episode: Finished after 9 steps：10Average = 9.6
# 382 Episode: Finished after 10 steps：10Average = 9.6
# 383 Episode: Finished after 9 steps：10Average = 9.5
# 384 Episode: Finished after 13 steps：10Average = 9.9
# 385 Episode: Finished after 9 steps：10Average = 9.8
# 386 Episode: Finished after 9 steps：10Average = 9.7
# 387 Episode: Finished after 11 steps：10Average = 9.9
# 388 Episode: Finished after 16 steps：10Average = 10.7
# 389 Episode: Finished after 10 steps：10Average = 10.7
# 390 Episode: Finished after 10 steps：10Average = 10.6
# 391 Episode: Finished after 11 steps：10Average = 10.8
# 392 Episode: Finished after 10 steps：10Average = 10.8
# 393 Episode: Finished after 18 steps：10Average = 11.7
# 394 Episode: Finished after 8 steps：10Average = 11.2
# 395 Episode: Finished after 9 steps：10Average = 11.2
# 396 Episode: Finished after 10 steps：10Average = 11.3
# 397 Episode: Finished after 10 steps：10Average = 11.2
# 398 Episode: Finished after 9 steps：10Average = 10.5
# 399 Episode: Finished after 8 steps：10Average = 10.3
# 400 Episode: Finished after 9 steps：10Average = 10.2
# 401 Episode: Finished after 9 steps：10Average = 10.0
# 402 Episode: Finished after 10 steps：10Average = 10.0
# 403 Episode: Finished after 10 steps：10Average = 9.2
# 404 Episode: Finished after 10 steps：10Average = 9.4
# 405 Episode: Finished after 9 steps：10Average = 9.4
# 406 Episode: Finished after 9 steps：10Average = 9.3
# 407 Episode: Finished after 9 steps：10Average = 9.2
# 408 Episode: Finished after 10 steps：10Average = 9.3
# 409 Episode: Finished after 10 steps：10Average = 9.5
# 410 Episode: Finished after 9 steps：10Average = 9.5
# 411 Episode: Finished after 10 steps：10Average = 9.6
# 412 Episode: Finished after 9 steps：10Average = 9.5
# 413 Episode: Finished after 10 steps：10Average = 9.5
# 414 Episode: Finished after 9 steps：10Average = 9.4
# 415 Episode: Finished after 10 steps：10Average = 9.5
# 416 Episode: Finished after 10 steps：10Average = 9.6
# 417 Episode: Finished after 10 steps：10Average = 9.7
# 418 Episode: Finished after 11 steps：10Average = 9.8
# 419 Episode: Finished after 11 steps：10Average = 9.9
# 420 Episode: Finished after 19 steps：10Average = 10.9
# 421 Episode: Finished after 11 steps：10Average = 11.0
# 422 Episode: Finished after 9 steps：10Average = 11.0
# 423 Episode: Finished after 11 steps：10Average = 11.1
# 424 Episode: Finished after 12 steps：10Average = 11.4
# 425 Episode: Finished after 10 steps：10Average = 11.4
# 426 Episode: Finished after 14 steps：10Average = 11.8
# 427 Episode: Finished after 9 steps：10Average = 11.7
# 428 Episode: Finished after 10 steps：10Average = 11.6
# 429 Episode: Finished after 9 steps：10Average = 11.4
# 430 Episode: Finished after 9 steps：10Average = 10.4
# 431 Episode: Finished after 10 steps：10Average = 10.3
# 432 Episode: Finished after 10 steps：10Average = 10.4
# 433 Episode: Finished after 11 steps：10Average = 10.4
# 434 Episode: Finished after 14 steps：10Average = 10.6
# 435 Episode: Finished after 11 steps：10Average = 10.7
# 436 Episode: Finished after 10 steps：10Average = 10.3
# 437 Episode: Finished after 10 steps：10Average = 10.4
# 438 Episode: Finished after 9 steps：10Average = 10.3
# 439 Episode: Finished after 10 steps：10Average = 10.4
# 440 Episode: Finished after 9 steps：10Average = 10.4
# 441 Episode: Finished after 10 steps：10Average = 10.4
# 442 Episode: Finished after 9 steps：10Average = 10.3
# 443 Episode: Finished after 12 steps：10Average = 10.4
# 444 Episode: Finished after 13 steps：10Average = 10.3
# 445 Episode: Finished after 9 steps：10Average = 10.1
# 446 Episode: Finished after 9 steps：10Average = 10.0
# 447 Episode: Finished after 11 steps：10Average = 10.1
# 448 Episode: Finished after 14 steps：10Average = 10.6
# 449 Episode: Finished after 10 steps：10Average = 10.6
# 450 Episode: Finished after 10 steps：10Average = 10.7
# 451 Episode: Finished after 10 steps：10Average = 10.7
# 452 Episode: Finished after 10 steps：10Average = 10.8
# 453 Episode: Finished after 12 steps：10Average = 10.8
# 454 Episode: Finished after 10 steps：10Average = 10.5
# 455 Episode: Finished after 10 steps：10Average = 10.6
# 456 Episode: Finished after 9 steps：10Average = 10.6
# 457 Episode: Finished after 18 steps：10Average = 11.3
# 458 Episode: Finished after 8 steps：10Average = 10.7
# 459 Episode: Finished after 11 steps：10Average = 10.8
# 460 Episode: Finished after 9 steps：10Average = 10.7
# 461 Episode: Finished after 18 steps：10Average = 11.5
# 462 Episode: Finished after 9 steps：10Average = 11.4
# 463 Episode: Finished after 11 steps：10Average = 11.3
# 464 Episode: Finished after 21 steps：10Average = 12.4
# 465 Episode: Finished after 10 steps：10Average = 12.4
# 466 Episode: Finished after 13 steps：10Average = 12.8
# 467 Episode: Finished after 11 steps：10Average = 12.1
# 468 Episode: Finished after 8 steps：10Average = 12.1
# 469 Episode: Finished after 9 steps：10Average = 11.9
# 470 Episode: Finished after 9 steps：10Average = 11.9
# 471 Episode: Finished after 10 steps：10Average = 11.1
# 472 Episode: Finished after 10 steps：10Average = 11.2
# 473 Episode: Finished after 14 steps：10Average = 11.5
# 474 Episode: Finished after 15 steps：10Average = 10.9
# 475 Episode: Finished after 11 steps：10Average = 11.0
# 476 Episode: Finished after 17 steps：10Average = 11.4
# 477 Episode: Finished after 10 steps：10Average = 11.3
# 478 Episode: Finished after 10 steps：10Average = 11.5
# 479 Episode: Finished after 12 steps：10Average = 11.8
# 480 Episode: Finished after 10 steps：10Average = 11.9
# 481 Episode: Finished after 9 steps：10Average = 11.8
# 482 Episode: Finished after 9 steps：10Average = 11.7
# 483 Episode: Finished after 9 steps：10Average = 11.2
# 484 Episode: Finished after 16 steps：10Average = 11.3
# 485 Episode: Finished after 11 steps：10Average = 11.3
# 486 Episode: Finished after 10 steps：10Average = 10.6
# 487 Episode: Finished after 9 steps：10Average = 10.5
# 488 Episode: Finished after 11 steps：10Average = 10.6
# 489 Episode: Finished after 20 steps：10Average = 11.4
# 490 Episode: Finished after 10 steps：10Average = 11.4
# 491 Episode: Finished after 16 steps：10Average = 12.1
# 492 Episode: Finished after 10 steps：10Average = 12.2
# 493 Episode: Finished after 9 steps：10Average = 12.2
# 494 Episode: Finished after 20 steps：10Average = 12.6
# 495 Episode: Finished after 9 steps：10Average = 12.4
# 496 Episode: Finished after 15 steps：10Average = 12.9
# 497 Episode: Finished after 14 steps：10Average = 13.4
# 498 Episode: Finished after 14 steps：10Average = 13.7
# 499 Episode: Finished after 11 steps：10Average = 12.8
